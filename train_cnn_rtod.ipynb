# %% [markdown]
# Resources Used
# - wget.download('https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/da4babe668a8afb093cc7776d7e630f3/generate_tfrecord.py')
# - Setup https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html

# %% [markdown]
# # 0. LOAD virtual environment

# %%
# terminal command - isntall requirements txt
pip install -r requirements.txt

# %% [markdown]
# # 1. SETUP paths

# %%
WORKSPACE_PATH = 'Tensorflow/workspace'
SCRIPTS_PATH = 'Tensorflow/scripts'
APIMODEL_PATH = 'Tensorflow/models'
ANNOTATION_PATH = WORKSPACE_PATH+'/annotations'
IMAGE_PATH = WORKSPACE_PATH+'/images'
MODEL_PATH = WORKSPACE_PATH+'/models'
PRETRAINED_MODEL_PATH = WORKSPACE_PATH+'/pre-trained-models'
CONFIG_PATH = MODEL_PATH+'/my_ssd_mobnet/pipeline.config'
CHECKPOINT_PATH = MODEL_PATH+'/my_ssd_mobnet/'

# %% [markdown]
# # 2. CREATE label maps

# %% [markdown]
# **- UPDATE glosses incl. sequential id -**

# %%
# create the dictionary entries for all glosses the model shall be trained on - MAKE SURE the naming exactly matches labelimg - ad add sequential IDs
labels = [
    # youtube_sample_glosses
    # {'name':'hello', 'id':1}, 
    # {'name':'yes', 'id':2}, 
    # {'name':'no', 'id':3}, 
    # {'name':'thanks', 'id':4}, 
    # {'name':'i love you', 'id':5}, 

    # phoenix_only_glosses
    {'name':'montag', 'id':1},    
    {'name':'auch', 'id':2},  
    {'name':'mehr', 'id':3},  
    {'name':'wolke', 'id':4},  
    {'name':'als', 'id':5},  
    {'name':'sonne', 'id':6},  
    {'name':'ueberwiegend', 'id':7},  
    {'name':'regen', 'id':8},  
    {'name':'gewitter', 'id':9},  

    # all_glosses (sample + phoenix)
    # {'name':'hello', 'id':1}, 
    # {'name':'yes', 'id':2}, 
    # {'name':'no', 'id':3}, 
    # {'name':'thanks', 'id':4}, 
    # {'name':'i love you', 'id':5}, 
    # {'name':'montag', 'id':6},    
    # {'name':'auch', 'id':7},  
    # {'name':'mehr', 'id':8},  
    # {'name':'wolke', 'id':9},  
    # {'name':'als', 'id':10},  
    # {'name':'sonne', 'id':11},  
    # {'name':'ueberwiegend', 'id':12},  
    # {'name':'regen', 'id':13},  
    # {'name':'gewitter', 'id':14}, 
    ]

with open(ANNOTATION_PATH + '/label_map.pbtxt', 'w') as f:
    for label in labels:
        f.write('item {\n') # space removed
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. CREATE tfrecord file

# %%
# downloading pretrained tf models from tf model zoo
# !cd Tensorflow && git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 99198, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 99198 (delta 52), reused 27 (delta 27), pack-reused 99119 (from 5)
# Receiving objects: 100% (99198/99198), 622.89 MiB | 30.48 MiB/s, done.
# Resolving deltas: 100% (72099/72099), done.

# %%
# installing object detection module (see command box below, keeping comment & command in same code created issues)

# %%
# %%bash
# cd Tensorflow/models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf1/setup.py . # updated to tf1
# python -m pip install .
# Out:
# Processing /Users/maximilianscheel/neuefische/capstone_project/sl_tf/Tensorflow/models/research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pillow in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (11.1.0)
# Requirement already satisfied: lxml in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (5.3.0)
# Requirement already satisfied: matplotlib in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (3.10.0)
# Requirement already satisfied: Cython in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (3.0.11)
# Requirement already satisfied: contextlib2 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.1.0)
# Requirement already satisfied: six in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.17.0)
# Requirement already satisfied: pycocotools in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (2.0.8)
# Requirement already satisfied: lvis in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.15.1)
# Requirement already satisfied: pandas in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from object_detection==0.1) (2.2.3)
# Requirement already satisfied: cycler>=0.10.0 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (1.4.8)
# Requirement already satisfied: numpy>=1.18.2 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (4.11.0.86)
# Requirement already satisfied: pyparsing>=2.4.0 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (4.55.8)
# Requirement already satisfied: packaging>=20.0 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (24.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2025.1)
# Requirement already satisfied: absl-py>=0.2.2 in /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages (from tf-slim->object_detection==0.1) (1.4.0)
# Building wheels for collected packages: object_detection
#   Building wheel for object_detection (setup.py): started
#   Building wheel for object_detection (setup.py): finished with status 'done'
#   Created wheel for object_detection: filename=object_detection-0.1-py3-none-any.whl size=1660107 sha256=04dc06b41353905783d3229e62d1546256298d80bb6eaff8e6af9be9676c6c18
#   Stored in directory: /private/var/folders/y5/l0vddhks2fj4y_tkywmly1240000gn/T/pip-ephem-wheel-cache-0syo4uyk/wheels/9a/03/91/43a4aae591c230a7d51d6736fac3bcb01c652d9a989f943d8d
# Successfully built object_detection
# Installing collected packages: object_detection
# Successfully installed object_detection-0.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **- UPDATE line of code canvas.py -**

# %%
# update line of code in .venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py

"""
replace
from tensorflow.python.keras.layers.preprocessing import image_preprocessing as image_ops 
with
from tensorflow.keras.preprocessing import image as image_ops
"""


import os

# Define the path to the Python file
file_path = ".venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py"

# Define the lines to be replaced
old_line = "from tensorflow.python.keras.layers.preprocessing import image_preprocessing as image_ops"
new_line = "from tensorflow.keras.preprocessing import image as image_ops"

# Read the file and copy the old line as a comment, then add the new line
with open(file_path, 'r') as file:
    lines = file.readlines()

with open(file_path, 'w') as file:
    for line in lines:
        if old_line in line:
            file.write("# " + line)  # Comment out the old line
            file.write(new_line + '\n')  # Add the new line
        else:
            file.write(line)

print(f"Updated {file_path} with new import statement and commented out the old one.")
# Out:
# Updated .venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py with new import statement and commented out the old one.

# %%
# upgrade protobuf
# !pip install --upgrade protobuf
# Out:
# Requirement already satisfied: protobuf in ./.venv/lib/python3.10/site-packages (3.20.3)
# Collecting protobuf
#   Using cached protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Using cached protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# tensorflow-macos 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.29.3 which is incompatible.
# Successfully installed protobuf-5.29.3
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x{IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. COPY model config to training folder

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' # model rerun with augmented training data - folder Tensorflow/models/my_ssd_mobnet needs to be deleted otherwise training model script will throw an error

# %%
# !mkdir -p {'Tensorflow/workspace/models/' + CUSTOM_MODEL_NAME}
# !cp {PRETRAINED_MODEL_PATH + '/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'} {MODEL_PATH + '/' + CUSTOM_MODEL_NAME}

# %% [markdown]
# # 5. UPDATE config for transfer learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
CONFIG_PATH = MODEL_PATH+'/'+CUSTOM_MODEL_NAME+'/pipeline.config'

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 9
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 4e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0
#            stddev: 0.01
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.997
#          scale: true
#          epsilon: 0.001
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10
#        x_scale: 10
#        height_scale: 5
#        width_scale: 5
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 4e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0
#              stddev: 0.01
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.997
#            scale: true
#            epsilon: 0.001
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.6
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4
#        aspect_ratios: 1
#        aspect_ratios: 2
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 1e-08
#        iou_threshold: 0.6
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1
#      localization_weight: 1
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 4
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3
#      min_area: 0.75
#      max_area: 1
#      overlap_thresh: 0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.08
#          total_steps: 50000
#          warmup_learning_rate: 0.026666
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.9
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "Tensorflow/workspace/pre-trained-models/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0"
#  num_steps: 50000
#  startup_delay_steps: 0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "detection"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "Tensorflow/workspace/annotations/label_map.pbtxt"
#  tf_record_input_reader {
#    input_path: "Tensorflow/workspace/annotations/train.record"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "Tensorflow/workspace/annotations/label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "Tensorflow/workspace/annotations/test.record"
#  }
#  ],
#  'eval_input_config': label_map_path: "Tensorflow/workspace/annotations/label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "Tensorflow/workspace/annotations/test.record"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %% [markdown]
# **- UPDATE no. of classes=glosses -**

# %%
pipeline_config.model.ssd.num_classes = 9 # UPDATE to the number of classes your model shall be trained on
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/train.record']
pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. TRAIN the model

# %%
# no. of steps set to 10000
print("""python {}/research/object_detection/model_main_tf2.py --model_dir={}/{} --pipeline_config_path={}/{}/pipeline.config --num_train_steps=10000""".format(APIMODEL_PATH, MODEL_PATH,CUSTOM_MODEL_NAME,MODEL_PATH,CUSTOM_MODEL_NAME))
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=10000

# %%
# copy paste python command to run the model 
# !python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=10000
# Out:
# /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0205 23:37:42.787131 8464107584 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I0205 23:37:42.800287 8464107584 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0205 23:37:42.800379 8464107584 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0205 23:37:42.812552 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0205 23:37:42.816364 8464107584 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0205 23:37:42.816423 8464107584 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0205 23:37:42.816447 8464107584 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0205 23:37:42.816464 8464107584 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0205 23:37:42.820289 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0205 23:37:42.829729 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0205 23:37:45.773669 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0205 23:37:46.995784 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0205 23:37:47.686205 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2025-02-05 23:37:48.750040: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0205 23:37:51.060342 13143928832 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0205 23:37:54.247037 14110715904 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0205 23:37:56.532243 14361325568 deprecation.py:569] From /Users/maximilianscheel/neuefische/capstone_project/sl_tf/.venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0205 23:37:56.844436 14361325568 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0205 23:37:58.493546 14428434432 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0205 23:38:00.030277 14525952000 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0205 23:38:01.634469 14630809600 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.446s
# I0205 23:38:40.846076 8464107584 model_lib_v2.py:705] Step 100 per-step time 0.446s
# INFO:tensorflow:{'Loss/classification_loss': 0.62056917,
#  'Loss/localization_loss': 0.4895847,
#  'Loss/regularization_loss': 0.15415594,
#  'Loss/total_loss': 1.2643099,
#  'learning_rate': 0.0319994}
# I0205 23:38:40.846821 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.62056917,
#  'Loss/localization_loss': 0.4895847,
#  'Loss/regularization_loss': 0.15415594,
#  'Loss/total_loss': 1.2643099,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.355s
# I0205 23:39:16.301040 8464107584 model_lib_v2.py:705] Step 200 per-step time 0.355s
# INFO:tensorflow:{'Loss/classification_loss': 0.3357303,
#  'Loss/localization_loss': 0.27449968,
#  'Loss/regularization_loss': 0.15433155,
#  'Loss/total_loss': 0.76456153,
#  'learning_rate': 0.0373328}
# I0205 23:39:16.301553 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.3357303,
#  'Loss/localization_loss': 0.27449968,
#  'Loss/regularization_loss': 0.15433155,
#  'Loss/total_loss': 0.76456153,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.398s
# I0205 23:39:56.122042 8464107584 model_lib_v2.py:705] Step 300 per-step time 0.398s
# INFO:tensorflow:{'Loss/classification_loss': 0.48608023,
#  'Loss/localization_loss': 0.3301391,
#  'Loss/regularization_loss': 0.15434903,
#  'Loss/total_loss': 0.97056836,
#  'learning_rate': 0.0426662}
# I0205 23:39:56.122625 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.48608023,
#  'Loss/localization_loss': 0.3301391,
#  'Loss/regularization_loss': 0.15434903,
#  'Loss/total_loss': 0.97056836,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.375s
# I0205 23:40:33.625456 8464107584 model_lib_v2.py:705] Step 400 per-step time 0.375s
# INFO:tensorflow:{'Loss/classification_loss': 0.36035976,
#  'Loss/localization_loss': 0.27348346,
#  'Loss/regularization_loss': 0.15441363,
#  'Loss/total_loss': 0.7882569,
#  'learning_rate': 0.047999598}
# I0205 23:40:33.626045 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.36035976,
#  'Loss/localization_loss': 0.27348346,
#  'Loss/regularization_loss': 0.15441363,
#  'Loss/total_loss': 0.7882569,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.350s
# I0205 23:41:08.655338 8464107584 model_lib_v2.py:705] Step 500 per-step time 0.350s
# INFO:tensorflow:{'Loss/classification_loss': 0.25444657,
#  'Loss/localization_loss': 0.1780598,
#  'Loss/regularization_loss': 0.15431601,
#  'Loss/total_loss': 0.5868224,
#  'learning_rate': 0.053333}
# I0205 23:41:08.655487 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.25444657,
#  'Loss/localization_loss': 0.1780598,
#  'Loss/regularization_loss': 0.15431601,
#  'Loss/total_loss': 0.5868224,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.354s
# I0205 23:41:44.084712 8464107584 model_lib_v2.py:705] Step 600 per-step time 0.354s
# INFO:tensorflow:{'Loss/classification_loss': 0.35872278,
#  'Loss/localization_loss': 0.17718945,
#  'Loss/regularization_loss': 0.15441445,
#  'Loss/total_loss': 0.6903267,
#  'learning_rate': 0.0586664}
# I0205 23:41:44.084865 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.35872278,
#  'Loss/localization_loss': 0.17718945,
#  'Loss/regularization_loss': 0.15441445,
#  'Loss/total_loss': 0.6903267,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.352s
# I0205 23:42:19.290275 8464107584 model_lib_v2.py:705] Step 700 per-step time 0.352s
# INFO:tensorflow:{'Loss/classification_loss': 0.3245033,
#  'Loss/localization_loss': 0.1500247,
#  'Loss/regularization_loss': 0.15437005,
#  'Loss/total_loss': 0.628898,
#  'learning_rate': 0.0639998}
# I0205 23:42:19.290531 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.3245033,
#  'Loss/localization_loss': 0.1500247,
#  'Loss/regularization_loss': 0.15437005,
#  'Loss/total_loss': 0.628898,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.350s
# I0205 23:42:54.239527 8464107584 model_lib_v2.py:705] Step 800 per-step time 0.350s
# INFO:tensorflow:{'Loss/classification_loss': 0.5740294,
#  'Loss/localization_loss': 0.19727042,
#  'Loss/regularization_loss': 0.15435444,
#  'Loss/total_loss': 0.9256543,
#  'learning_rate': 0.069333196}
# I0205 23:42:54.239674 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.5740294,
#  'Loss/localization_loss': 0.19727042,
#  'Loss/regularization_loss': 0.15435444,
#  'Loss/total_loss': 0.9256543,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.358s
# I0205 23:43:30.019552 8464107584 model_lib_v2.py:705] Step 900 per-step time 0.358s
# INFO:tensorflow:{'Loss/classification_loss': 0.28101382,
#  'Loss/localization_loss': 0.19192909,
#  'Loss/regularization_loss': 0.1541394,
#  'Loss/total_loss': 0.62708235,
#  'learning_rate': 0.074666604}
# I0205 23:43:30.019701 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.28101382,
#  'Loss/localization_loss': 0.19192909,
#  'Loss/regularization_loss': 0.1541394,
#  'Loss/total_loss': 0.62708235,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.355s
# I0205 23:44:05.495344 8464107584 model_lib_v2.py:705] Step 1000 per-step time 0.355s
# INFO:tensorflow:{'Loss/classification_loss': 0.29764065,
#  'Loss/localization_loss': 0.1665258,
#  'Loss/regularization_loss': 0.15392172,
#  'Loss/total_loss': 0.6180882,
#  'learning_rate': 0.08}
# I0205 23:44:05.495494 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.29764065,
#  'Loss/localization_loss': 0.1665258,
#  'Loss/regularization_loss': 0.15392172,
#  'Loss/total_loss': 0.6180882,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.362s
# I0205 23:44:41.730796 8464107584 model_lib_v2.py:705] Step 1100 per-step time 0.362s
# INFO:tensorflow:{'Loss/classification_loss': 0.34811333,
#  'Loss/localization_loss': 0.21888636,
#  'Loss/regularization_loss': 0.15386574,
#  'Loss/total_loss': 0.7208654,
#  'learning_rate': 0.07999918}
# I0205 23:44:41.731342 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.34811333,
#  'Loss/localization_loss': 0.21888636,
#  'Loss/regularization_loss': 0.15386574,
#  'Loss/total_loss': 0.7208654,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.365s
# I0205 23:45:18.261466 8464107584 model_lib_v2.py:705] Step 1200 per-step time 0.365s
# INFO:tensorflow:{'Loss/classification_loss': 0.21744092,
#  'Loss/localization_loss': 0.09115557,
#  'Loss/regularization_loss': 0.15361908,
#  'Loss/total_loss': 0.46221554,
#  'learning_rate': 0.079996705}
# I0205 23:45:18.261682 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.21744092,
#  'Loss/localization_loss': 0.09115557,
#  'Loss/regularization_loss': 0.15361908,
#  'Loss/total_loss': 0.46221554,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.426s
# I0205 23:46:00.831691 8464107584 model_lib_v2.py:705] Step 1300 per-step time 0.426s
# INFO:tensorflow:{'Loss/classification_loss': 0.09711421,
#  'Loss/localization_loss': 0.049419023,
#  'Loss/regularization_loss': 0.15324202,
#  'Loss/total_loss': 0.29977524,
#  'learning_rate': 0.0799926}
# I0205 23:46:00.832277 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.09711421,
#  'Loss/localization_loss': 0.049419023,
#  'Loss/regularization_loss': 0.15324202,
#  'Loss/total_loss': 0.29977524,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.344s
# I0205 23:46:35.244075 8464107584 model_lib_v2.py:705] Step 1400 per-step time 0.344s
# INFO:tensorflow:{'Loss/classification_loss': 0.33099198,
#  'Loss/localization_loss': 0.08404148,
#  'Loss/regularization_loss': 0.15286142,
#  'Loss/total_loss': 0.5678949,
#  'learning_rate': 0.07998685}
# I0205 23:46:35.244227 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.33099198,
#  'Loss/localization_loss': 0.08404148,
#  'Loss/regularization_loss': 0.15286142,
#  'Loss/total_loss': 0.5678949,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.336s
# I0205 23:47:08.871321 8464107584 model_lib_v2.py:705] Step 1500 per-step time 0.336s
# INFO:tensorflow:{'Loss/classification_loss': 0.21213044,
#  'Loss/localization_loss': 0.10349585,
#  'Loss/regularization_loss': 0.15247357,
#  'Loss/total_loss': 0.46809983,
#  'learning_rate': 0.07997945}
# I0205 23:47:08.871577 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.21213044,
#  'Loss/localization_loss': 0.10349585,
#  'Loss/regularization_loss': 0.15247357,
#  'Loss/total_loss': 0.46809983,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 9.582s
# I0206 00:03:07.075552 8464107584 model_lib_v2.py:705] Step 1600 per-step time 9.582s
# INFO:tensorflow:{'Loss/classification_loss': 0.11622965,
#  'Loss/localization_loss': 0.063903935,
#  'Loss/regularization_loss': 0.15193023,
#  'Loss/total_loss': 0.3320638,
#  'learning_rate': 0.079970405}
# I0206 00:03:07.076061 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11622965,
#  'Loss/localization_loss': 0.063903935,
#  'Loss/regularization_loss': 0.15193023,
#  'Loss/total_loss': 0.3320638,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.307s
# I0206 00:03:37.768012 8464107584 model_lib_v2.py:705] Step 1700 per-step time 0.307s
# INFO:tensorflow:{'Loss/classification_loss': 0.08634504,
#  'Loss/localization_loss': 0.04689074,
#  'Loss/regularization_loss': 0.1513542,
#  'Loss/total_loss': 0.28458998,
#  'learning_rate': 0.07995972}
# I0206 00:03:37.768131 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08634504,
#  'Loss/localization_loss': 0.04689074,
#  'Loss/regularization_loss': 0.1513542,
#  'Loss/total_loss': 0.28458998,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 9.595s
# I0206 00:19:37.224101 8464107584 model_lib_v2.py:705] Step 1800 per-step time 9.595s
# INFO:tensorflow:{'Loss/classification_loss': 0.06971983,
#  'Loss/localization_loss': 0.06580541,
#  'Loss/regularization_loss': 0.15081891,
#  'Loss/total_loss': 0.28634414,
#  'learning_rate': 0.0799474}
# I0206 00:19:37.224617 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06971983,
#  'Loss/localization_loss': 0.06580541,
#  'Loss/regularization_loss': 0.15081891,
#  'Loss/total_loss': 0.28634414,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 9.564s
# I0206 00:35:33.647136 8464107584 model_lib_v2.py:705] Step 1900 per-step time 9.564s
# INFO:tensorflow:{'Loss/classification_loss': 0.15322319,
#  'Loss/localization_loss': 0.12339794,
#  'Loss/regularization_loss': 0.15036029,
#  'Loss/total_loss': 0.42698142,
#  'learning_rate': 0.07993342}
# I0206 00:35:33.647642 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.15322319,
#  'Loss/localization_loss': 0.12339794,
#  'Loss/regularization_loss': 0.15036029,
#  'Loss/total_loss': 0.42698142,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.308s
# I0206 00:36:04.421261 8464107584 model_lib_v2.py:705] Step 2000 per-step time 0.308s
# INFO:tensorflow:{'Loss/classification_loss': 0.13488828,
#  'Loss/localization_loss': 0.045425683,
#  'Loss/regularization_loss': 0.14981985,
#  'Loss/total_loss': 0.33013383,
#  'learning_rate': 0.07991781}
# I0206 00:36:04.421381 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.13488828,
#  'Loss/localization_loss': 0.045425683,
#  'Loss/regularization_loss': 0.14981985,
#  'Loss/total_loss': 0.33013383,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 9.572s
# I0206 00:52:01.577149 8464107584 model_lib_v2.py:705] Step 2100 per-step time 9.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.10376842,
#  'Loss/localization_loss': 0.07919126,
#  'Loss/regularization_loss': 0.14930844,
#  'Loss/total_loss': 0.33226812,
#  'learning_rate': 0.07990056}
# I0206 00:52:01.577691 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10376842,
#  'Loss/localization_loss': 0.07919126,
#  'Loss/regularization_loss': 0.14930844,
#  'Loss/total_loss': 0.33226812,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 9.559s
# I0206 01:07:57.492751 8464107584 model_lib_v2.py:705] Step 2200 per-step time 9.559s
# INFO:tensorflow:{'Loss/classification_loss': 0.13803753,
#  'Loss/localization_loss': 0.073908746,
#  'Loss/regularization_loss': 0.14873,
#  'Loss/total_loss': 0.3606763,
#  'learning_rate': 0.07988167}
# I0206 01:07:57.492872 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.13803753,
#  'Loss/localization_loss': 0.073908746,
#  'Loss/regularization_loss': 0.14873,
#  'Loss/total_loss': 0.3606763,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.308s
# I0206 01:08:28.297733 8464107584 model_lib_v2.py:705] Step 2300 per-step time 0.308s
# INFO:tensorflow:{'Loss/classification_loss': 0.110302925,
#  'Loss/localization_loss': 0.07742124,
#  'Loss/regularization_loss': 0.14821956,
#  'Loss/total_loss': 0.33594373,
#  'learning_rate': 0.07986114}
# I0206 01:08:28.297882 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.110302925,
#  'Loss/localization_loss': 0.07742124,
#  'Loss/regularization_loss': 0.14821956,
#  'Loss/total_loss': 0.33594373,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.308s
# I0206 01:08:59.049099 8464107584 model_lib_v2.py:705] Step 2400 per-step time 0.308s
# INFO:tensorflow:{'Loss/classification_loss': 0.18778771,
#  'Loss/localization_loss': 0.13218054,
#  'Loss/regularization_loss': 0.14779326,
#  'Loss/total_loss': 0.46776152,
#  'learning_rate': 0.07983897}
# I0206 01:08:59.049313 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.18778771,
#  'Loss/localization_loss': 0.13218054,
#  'Loss/regularization_loss': 0.14779326,
#  'Loss/total_loss': 0.46776152,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 9.593s
# I0206 01:24:58.303954 8464107584 model_lib_v2.py:705] Step 2500 per-step time 9.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.12073519,
#  'Loss/localization_loss': 0.043094255,
#  'Loss/regularization_loss': 0.14725833,
#  'Loss/total_loss': 0.3110878,
#  'learning_rate': 0.079815164}
# I0206 01:24:58.304079 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12073519,
#  'Loss/localization_loss': 0.043094255,
#  'Loss/regularization_loss': 0.14725833,
#  'Loss/total_loss': 0.3110878,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.318s
# I0206 01:25:30.101539 8464107584 model_lib_v2.py:705] Step 2600 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.09280469,
#  'Loss/localization_loss': 0.05194485,
#  'Loss/regularization_loss': 0.14658062,
#  'Loss/total_loss': 0.29133016,
#  'learning_rate': 0.07978972}
# I0206 01:25:30.102082 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.09280469,
#  'Loss/localization_loss': 0.05194485,
#  'Loss/regularization_loss': 0.14658062,
#  'Loss/total_loss': 0.29133016,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.316s
# I0206 01:26:01.714892 8464107584 model_lib_v2.py:705] Step 2700 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.084170125,
#  'Loss/localization_loss': 0.07918963,
#  'Loss/regularization_loss': 0.14595126,
#  'Loss/total_loss': 0.309311,
#  'learning_rate': 0.07976264}
# I0206 01:26:01.715064 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.084170125,
#  'Loss/localization_loss': 0.07918963,
#  'Loss/regularization_loss': 0.14595126,
#  'Loss/total_loss': 0.309311,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.328s
# I0206 01:26:34.562664 8464107584 model_lib_v2.py:705] Step 2800 per-step time 0.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.105323434,
#  'Loss/localization_loss': 0.052007694,
#  'Loss/regularization_loss': 0.14539257,
#  'Loss/total_loss': 0.3027237,
#  'learning_rate': 0.07973392}
# I0206 01:26:34.562821 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.105323434,
#  'Loss/localization_loss': 0.052007694,
#  'Loss/regularization_loss': 0.14539257,
#  'Loss/total_loss': 0.3027237,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.339s
# I0206 01:27:08.471046 8464107584 model_lib_v2.py:705] Step 2900 per-step time 0.339s
# INFO:tensorflow:{'Loss/classification_loss': 0.14873718,
#  'Loss/localization_loss': 0.08772213,
#  'Loss/regularization_loss': 0.14473715,
#  'Loss/total_loss': 0.38119644,
#  'learning_rate': 0.07970358}
# I0206 01:27:08.471311 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.14873718,
#  'Loss/localization_loss': 0.08772213,
#  'Loss/regularization_loss': 0.14473715,
#  'Loss/total_loss': 0.38119644,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 9.574s
# I0206 01:43:05.910544 8464107584 model_lib_v2.py:705] Step 3000 per-step time 9.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.12421398,
#  'Loss/localization_loss': 0.057462517,
#  'Loss/regularization_loss': 0.14408676,
#  'Loss/total_loss': 0.32576326,
#  'learning_rate': 0.0796716}
# I0206 01:43:05.910671 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12421398,
#  'Loss/localization_loss': 0.057462517,
#  'Loss/regularization_loss': 0.14408676,
#  'Loss/total_loss': 0.32576326,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.313s
# I0206 01:43:37.163159 8464107584 model_lib_v2.py:705] Step 3100 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.085369036,
#  'Loss/localization_loss': 0.10364409,
#  'Loss/regularization_loss': 0.14364173,
#  'Loss/total_loss': 0.33265483,
#  'learning_rate': 0.07963799}
# I0206 01:43:37.163305 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.085369036,
#  'Loss/localization_loss': 0.10364409,
#  'Loss/regularization_loss': 0.14364173,
#  'Loss/total_loss': 0.33265483,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 2.188s
# I0206 01:47:15.948080 8464107584 model_lib_v2.py:705] Step 3200 per-step time 2.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.123245105,
#  'Loss/localization_loss': 0.077983536,
#  'Loss/regularization_loss': 0.14309986,
#  'Loss/total_loss': 0.34432852,
#  'learning_rate': 0.07960275}
# I0206 01:47:15.948595 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.123245105,
#  'Loss/localization_loss': 0.077983536,
#  'Loss/regularization_loss': 0.14309986,
#  'Loss/total_loss': 0.34432852,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 9.564s
# I0206 02:03:12.363994 8464107584 model_lib_v2.py:705] Step 3300 per-step time 9.564s
# INFO:tensorflow:{'Loss/classification_loss': 0.07811638,
#  'Loss/localization_loss': 0.03542562,
#  'Loss/regularization_loss': 0.14246091,
#  'Loss/total_loss': 0.2560029,
#  'learning_rate': 0.07956588}
# I0206 02:03:12.364535 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07811638,
#  'Loss/localization_loss': 0.03542562,
#  'Loss/regularization_loss': 0.14246091,
#  'Loss/total_loss': 0.2560029,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.312s
# I0206 02:03:43.571492 8464107584 model_lib_v2.py:705] Step 3400 per-step time 0.312s
# INFO:tensorflow:{'Loss/classification_loss': 0.100469686,
#  'Loss/localization_loss': 0.045246087,
#  'Loss/regularization_loss': 0.1418007,
#  'Loss/total_loss': 0.28751647,
#  'learning_rate': 0.079527386}
# I0206 02:03:43.571643 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.100469686,
#  'Loss/localization_loss': 0.045246087,
#  'Loss/regularization_loss': 0.1418007,
#  'Loss/total_loss': 0.28751647,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 9.560s
# I0206 02:19:39.550271 8464107584 model_lib_v2.py:705] Step 3500 per-step time 9.560s
# INFO:tensorflow:{'Loss/classification_loss': 0.10378543,
#  'Loss/localization_loss': 0.06378184,
#  'Loss/regularization_loss': 0.14113139,
#  'Loss/total_loss': 0.30869865,
#  'learning_rate': 0.07948727}
# I0206 02:19:39.550400 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10378543,
#  'Loss/localization_loss': 0.06378184,
#  'Loss/regularization_loss': 0.14113139,
#  'Loss/total_loss': 0.30869865,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.309s
# I0206 02:20:10.426840 8464107584 model_lib_v2.py:705] Step 3600 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.076016955,
#  'Loss/localization_loss': 0.032224625,
#  'Loss/regularization_loss': 0.14051004,
#  'Loss/total_loss': 0.24875161,
#  'learning_rate': 0.079445526}
# I0206 02:20:10.427358 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.076016955,
#  'Loss/localization_loss': 0.032224625,
#  'Loss/regularization_loss': 0.14051004,
#  'Loss/total_loss': 0.24875161,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 9.553s
# I0206 02:36:05.770650 8464107584 model_lib_v2.py:705] Step 3700 per-step time 9.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.0823925,
#  'Loss/localization_loss': 0.046073183,
#  'Loss/regularization_loss': 0.13985263,
#  'Loss/total_loss': 0.2683183,
#  'learning_rate': 0.07940216}
# I0206 02:36:05.770776 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0823925,
#  'Loss/localization_loss': 0.046073183,
#  'Loss/regularization_loss': 0.13985263,
#  'Loss/total_loss': 0.2683183,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 7.048s
# I0206 02:47:50.527950 8464107584 model_lib_v2.py:705] Step 3800 per-step time 7.048s
# INFO:tensorflow:{'Loss/classification_loss': 0.08675125,
#  'Loss/localization_loss': 0.02873539,
#  'Loss/regularization_loss': 0.13920483,
#  'Loss/total_loss': 0.25469148,
#  'learning_rate': 0.079357184}
# I0206 02:47:50.528080 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08675125,
#  'Loss/localization_loss': 0.02873539,
#  'Loss/regularization_loss': 0.13920483,
#  'Loss/total_loss': 0.25469148,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.313s
# I0206 02:48:21.869174 8464107584 model_lib_v2.py:705] Step 3900 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.116922736,
#  'Loss/localization_loss': 0.022746617,
#  'Loss/regularization_loss': 0.13853236,
#  'Loss/total_loss': 0.2782017,
#  'learning_rate': 0.07931058}
# I0206 02:48:21.869747 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.116922736,
#  'Loss/localization_loss': 0.022746617,
#  'Loss/regularization_loss': 0.13853236,
#  'Loss/total_loss': 0.2782017,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.321s
# I0206 02:48:53.923028 8464107584 model_lib_v2.py:705] Step 4000 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.1102465,
#  'Loss/localization_loss': 0.04000528,
#  'Loss/regularization_loss': 0.13789201,
#  'Loss/total_loss': 0.28814378,
#  'learning_rate': 0.07926236}
# I0206 02:48:53.923629 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1102465,
#  'Loss/localization_loss': 0.04000528,
#  'Loss/regularization_loss': 0.13789201,
#  'Loss/total_loss': 0.28814378,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.325s
# I0206 02:49:26.393476 8464107584 model_lib_v2.py:705] Step 4100 per-step time 0.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.07628817,
#  'Loss/localization_loss': 0.050648462,
#  'Loss/regularization_loss': 0.13724756,
#  'Loss/total_loss': 0.2641842,
#  'learning_rate': 0.07921253}
# I0206 02:49:26.393630 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07628817,
#  'Loss/localization_loss': 0.050648462,
#  'Loss/regularization_loss': 0.13724756,
#  'Loss/total_loss': 0.2641842,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.336s
# I0206 02:49:59.957359 8464107584 model_lib_v2.py:705] Step 4200 per-step time 0.336s
# INFO:tensorflow:{'Loss/classification_loss': 0.068844065,
#  'Loss/localization_loss': 0.058129895,
#  'Loss/regularization_loss': 0.13659021,
#  'Loss/total_loss': 0.26356417,
#  'learning_rate': 0.07916109}
# I0206 02:49:59.957524 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.068844065,
#  'Loss/localization_loss': 0.058129895,
#  'Loss/regularization_loss': 0.13659021,
#  'Loss/total_loss': 0.26356417,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.334s
# I0206 02:50:33.372280 8464107584 model_lib_v2.py:705] Step 4300 per-step time 0.334s
# INFO:tensorflow:{'Loss/classification_loss': 0.107957095,
#  'Loss/localization_loss': 0.04686998,
#  'Loss/regularization_loss': 0.13592051,
#  'Loss/total_loss': 0.29074758,
#  'learning_rate': 0.07910804}
# I0206 02:50:33.372442 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.107957095,
#  'Loss/localization_loss': 0.04686998,
#  'Loss/regularization_loss': 0.13592051,
#  'Loss/total_loss': 0.29074758,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.341s
# I0206 02:51:07.435564 8464107584 model_lib_v2.py:705] Step 4400 per-step time 0.341s
# INFO:tensorflow:{'Loss/classification_loss': 0.1358888,
#  'Loss/localization_loss': 0.0453707,
#  'Loss/regularization_loss': 0.13530847,
#  'Loss/total_loss': 0.31656796,
#  'learning_rate': 0.07905338}
# I0206 02:51:07.436168 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1358888,
#  'Loss/localization_loss': 0.0453707,
#  'Loss/regularization_loss': 0.13530847,
#  'Loss/total_loss': 0.31656796,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.338s
# I0206 02:51:41.278929 8464107584 model_lib_v2.py:705] Step 4500 per-step time 0.338s
# INFO:tensorflow:{'Loss/classification_loss': 0.09372231,
#  'Loss/localization_loss': 0.021194132,
#  'Loss/regularization_loss': 0.13468175,
#  'Loss/total_loss': 0.24959819,
#  'learning_rate': 0.07899711}
# I0206 02:51:41.279079 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.09372231,
#  'Loss/localization_loss': 0.021194132,
#  'Loss/regularization_loss': 0.13468175,
#  'Loss/total_loss': 0.24959819,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.344s
# I0206 02:52:15.650319 8464107584 model_lib_v2.py:705] Step 4600 per-step time 0.344s
# INFO:tensorflow:{'Loss/classification_loss': 0.08631861,
#  'Loss/localization_loss': 0.028093105,
#  'Loss/regularization_loss': 0.13406263,
#  'Loss/total_loss': 0.24847436,
#  'learning_rate': 0.078939244}
# I0206 02:52:15.650474 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08631861,
#  'Loss/localization_loss': 0.028093105,
#  'Loss/regularization_loss': 0.13406263,
#  'Loss/total_loss': 0.24847436,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.363s
# I0206 02:52:51.984387 8464107584 model_lib_v2.py:705] Step 4700 per-step time 0.363s
# INFO:tensorflow:{'Loss/classification_loss': 0.10481871,
#  'Loss/localization_loss': 0.033766568,
#  'Loss/regularization_loss': 0.13341524,
#  'Loss/total_loss': 0.27200052,
#  'learning_rate': 0.07887978}
# I0206 02:52:51.985090 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10481871,
#  'Loss/localization_loss': 0.033766568,
#  'Loss/regularization_loss': 0.13341524,
#  'Loss/total_loss': 0.27200052,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.350s
# I0206 02:53:27.001933 8464107584 model_lib_v2.py:705] Step 4800 per-step time 0.350s
# INFO:tensorflow:{'Loss/classification_loss': 0.08526571,
#  'Loss/localization_loss': 0.022632273,
#  'Loss/regularization_loss': 0.13279662,
#  'Loss/total_loss': 0.2406946,
#  'learning_rate': 0.07881871}
# I0206 02:53:27.002096 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08526571,
#  'Loss/localization_loss': 0.022632273,
#  'Loss/regularization_loss': 0.13279662,
#  'Loss/total_loss': 0.2406946,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.349s
# I0206 02:54:01.903508 8464107584 model_lib_v2.py:705] Step 4900 per-step time 0.349s
# INFO:tensorflow:{'Loss/classification_loss': 0.13469845,
#  'Loss/localization_loss': 0.033583336,
#  'Loss/regularization_loss': 0.1321846,
#  'Loss/total_loss': 0.3004664,
#  'learning_rate': 0.07875605}
# I0206 02:54:01.903661 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.13469845,
#  'Loss/localization_loss': 0.033583336,
#  'Loss/regularization_loss': 0.1321846,
#  'Loss/total_loss': 0.3004664,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.349s
# I0206 02:54:36.778030 8464107584 model_lib_v2.py:705] Step 5000 per-step time 0.349s
# INFO:tensorflow:{'Loss/classification_loss': 0.10631584,
#  'Loss/localization_loss': 0.032339603,
#  'Loss/regularization_loss': 0.13155456,
#  'Loss/total_loss': 0.27021,
#  'learning_rate': 0.078691795}
# I0206 02:54:36.778180 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10631584,
#  'Loss/localization_loss': 0.032339603,
#  'Loss/regularization_loss': 0.13155456,
#  'Loss/total_loss': 0.27021,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.356s
# I0206 02:55:12.373030 8464107584 model_lib_v2.py:705] Step 5100 per-step time 0.356s
# INFO:tensorflow:{'Loss/classification_loss': 0.0647652,
#  'Loss/localization_loss': 0.038095392,
#  'Loss/regularization_loss': 0.13095668,
#  'Loss/total_loss': 0.23381728,
#  'learning_rate': 0.07862595}
# I0206 02:55:12.373690 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0647652,
#  'Loss/localization_loss': 0.038095392,
#  'Loss/regularization_loss': 0.13095668,
#  'Loss/total_loss': 0.23381728,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.356s
# I0206 02:55:47.986935 8464107584 model_lib_v2.py:705] Step 5200 per-step time 0.356s
# INFO:tensorflow:{'Loss/classification_loss': 0.11178289,
#  'Loss/localization_loss': 0.020689417,
#  'Loss/regularization_loss': 0.13034427,
#  'Loss/total_loss': 0.26281658,
#  'learning_rate': 0.07855851}
# I0206 02:55:47.987088 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11178289,
#  'Loss/localization_loss': 0.020689417,
#  'Loss/regularization_loss': 0.13034427,
#  'Loss/total_loss': 0.26281658,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.352s
# I0206 02:56:23.192060 8464107584 model_lib_v2.py:705] Step 5300 per-step time 0.352s
# INFO:tensorflow:{'Loss/classification_loss': 0.04980563,
#  'Loss/localization_loss': 0.021763504,
#  'Loss/regularization_loss': 0.12971176,
#  'Loss/total_loss': 0.20128089,
#  'learning_rate': 0.07848949}
# I0206 02:56:23.192203 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.04980563,
#  'Loss/localization_loss': 0.021763504,
#  'Loss/regularization_loss': 0.12971176,
#  'Loss/total_loss': 0.20128089,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.355s
# I0206 02:56:58.643899 8464107584 model_lib_v2.py:705] Step 5400 per-step time 0.355s
# INFO:tensorflow:{'Loss/classification_loss': 0.08641642,
#  'Loss/localization_loss': 0.021849934,
#  'Loss/regularization_loss': 0.12909177,
#  'Loss/total_loss': 0.23735812,
#  'learning_rate': 0.078418896}
# I0206 02:56:58.644157 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08641642,
#  'Loss/localization_loss': 0.021849934,
#  'Loss/regularization_loss': 0.12909177,
#  'Loss/total_loss': 0.23735812,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.354s
# I0206 02:57:34.005480 8464107584 model_lib_v2.py:705] Step 5500 per-step time 0.354s
# INFO:tensorflow:{'Loss/classification_loss': 0.11904489,
#  'Loss/localization_loss': 0.031358536,
#  'Loss/regularization_loss': 0.12850027,
#  'Loss/total_loss': 0.2789037,
#  'learning_rate': 0.078346714}
# I0206 02:57:34.005637 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11904489,
#  'Loss/localization_loss': 0.031358536,
#  'Loss/regularization_loss': 0.12850027,
#  'Loss/total_loss': 0.2789037,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.365s
# I0206 02:58:10.456751 8464107584 model_lib_v2.py:705] Step 5600 per-step time 0.365s
# INFO:tensorflow:{'Loss/classification_loss': 0.15147197,
#  'Loss/localization_loss': 0.04367673,
#  'Loss/regularization_loss': 0.12791924,
#  'Loss/total_loss': 0.32306796,
#  'learning_rate': 0.07827295}
# I0206 02:58:10.456901 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.15147197,
#  'Loss/localization_loss': 0.04367673,
#  'Loss/regularization_loss': 0.12791924,
#  'Loss/total_loss': 0.32306796,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.358s
# I0206 02:58:46.254493 8464107584 model_lib_v2.py:705] Step 5700 per-step time 0.358s
# INFO:tensorflow:{'Loss/classification_loss': 0.11231162,
#  'Loss/localization_loss': 0.035743244,
#  'Loss/regularization_loss': 0.12736563,
#  'Loss/total_loss': 0.2754205,
#  'learning_rate': 0.07819763}
# I0206 02:58:46.255216 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11231162,
#  'Loss/localization_loss': 0.035743244,
#  'Loss/regularization_loss': 0.12736563,
#  'Loss/total_loss': 0.2754205,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.356s
# I0206 02:59:21.874552 8464107584 model_lib_v2.py:705] Step 5800 per-step time 0.356s
# INFO:tensorflow:{'Loss/classification_loss': 0.10244775,
#  'Loss/localization_loss': 0.05703666,
#  'Loss/regularization_loss': 0.1268216,
#  'Loss/total_loss': 0.28630602,
#  'learning_rate': 0.07812072}
# I0206 02:59:21.874714 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10244775,
#  'Loss/localization_loss': 0.05703666,
#  'Loss/regularization_loss': 0.1268216,
#  'Loss/total_loss': 0.28630602,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.362s
# I0206 02:59:58.075246 8464107584 model_lib_v2.py:705] Step 5900 per-step time 0.362s
# INFO:tensorflow:{'Loss/classification_loss': 0.03803661,
#  'Loss/localization_loss': 0.029388573,
#  'Loss/regularization_loss': 0.12624986,
#  'Loss/total_loss': 0.19367506,
#  'learning_rate': 0.078042254}
# I0206 02:59:58.075427 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.03803661,
#  'Loss/localization_loss': 0.029388573,
#  'Loss/regularization_loss': 0.12624986,
#  'Loss/total_loss': 0.19367506,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.355s
# I0206 03:00:33.576422 8464107584 model_lib_v2.py:705] Step 6000 per-step time 0.355s
# INFO:tensorflow:{'Loss/classification_loss': 0.0693109,
#  'Loss/localization_loss': 0.027394008,
#  'Loss/regularization_loss': 0.12563448,
#  'Loss/total_loss': 0.22233939,
#  'learning_rate': 0.07796223}
# I0206 03:00:33.576587 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0693109,
#  'Loss/localization_loss': 0.027394008,
#  'Loss/regularization_loss': 0.12563448,
#  'Loss/total_loss': 0.22233939,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.371s
# I0206 03:01:10.680125 8464107584 model_lib_v2.py:705] Step 6100 per-step time 0.371s
# INFO:tensorflow:{'Loss/classification_loss': 0.16921872,
#  'Loss/localization_loss': 0.03502773,
#  'Loss/regularization_loss': 0.12507229,
#  'Loss/total_loss': 0.32931873,
#  'learning_rate': 0.077880636}
# I0206 03:01:10.680298 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.16921872,
#  'Loss/localization_loss': 0.03502773,
#  'Loss/regularization_loss': 0.12507229,
#  'Loss/total_loss': 0.32931873,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.389s
# I0206 03:01:49.604521 8464107584 model_lib_v2.py:705] Step 6200 per-step time 0.389s
# INFO:tensorflow:{'Loss/classification_loss': 0.07662212,
#  'Loss/localization_loss': 0.033685718,
#  'Loss/regularization_loss': 0.124532826,
#  'Loss/total_loss': 0.23484066,
#  'learning_rate': 0.07779749}
# I0206 03:01:49.605327 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07662212,
#  'Loss/localization_loss': 0.033685718,
#  'Loss/regularization_loss': 0.124532826,
#  'Loss/total_loss': 0.23484066,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.406s
# I0206 03:02:30.250002 8464107584 model_lib_v2.py:705] Step 6300 per-step time 0.406s
# INFO:tensorflow:{'Loss/classification_loss': 0.11664757,
#  'Loss/localization_loss': 0.026836038,
#  'Loss/regularization_loss': 0.12396088,
#  'Loss/total_loss': 0.2674445,
#  'learning_rate': 0.07771279}
# I0206 03:02:30.250212 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11664757,
#  'Loss/localization_loss': 0.026836038,
#  'Loss/regularization_loss': 0.12396088,
#  'Loss/total_loss': 0.2674445,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.416s
# I0206 03:03:11.813642 8464107584 model_lib_v2.py:705] Step 6400 per-step time 0.416s
# INFO:tensorflow:{'Loss/classification_loss': 0.054851264,
#  'Loss/localization_loss': 0.014064987,
#  'Loss/regularization_loss': 0.123382054,
#  'Loss/total_loss': 0.19229831,
#  'learning_rate': 0.077626534}
# I0206 03:03:11.813854 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.054851264,
#  'Loss/localization_loss': 0.014064987,
#  'Loss/regularization_loss': 0.123382054,
#  'Loss/total_loss': 0.19229831,
#  'learning_rate': 0.077626534}
# INFO:tensorflow:Step 6500 per-step time 0.419s
# I0206 03:03:53.715164 8464107584 model_lib_v2.py:705] Step 6500 per-step time 0.419s
# INFO:tensorflow:{'Loss/classification_loss': 0.067169204,
#  'Loss/localization_loss': 0.015955219,
#  'Loss/regularization_loss': 0.12278925,
#  'Loss/total_loss': 0.20591366,
#  'learning_rate': 0.077538736}
# I0206 03:03:53.715389 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.067169204,
#  'Loss/localization_loss': 0.015955219,
#  'Loss/regularization_loss': 0.12278925,
#  'Loss/total_loss': 0.20591366,
#  'learning_rate': 0.077538736}
# INFO:tensorflow:Step 6600 per-step time 0.418s
# I0206 03:04:35.540495 8464107584 model_lib_v2.py:705] Step 6600 per-step time 0.418s
# INFO:tensorflow:{'Loss/classification_loss': 0.07271025,
#  'Loss/localization_loss': 0.028327378,
#  'Loss/regularization_loss': 0.12222744,
#  'Loss/total_loss': 0.22326508,
#  'learning_rate': 0.07744939}
# I0206 03:04:35.540838 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07271025,
#  'Loss/localization_loss': 0.028327378,
#  'Loss/regularization_loss': 0.12222744,
#  'Loss/total_loss': 0.22326508,
#  'learning_rate': 0.07744939}
# INFO:tensorflow:Step 6700 per-step time 0.422s
# I0206 03:05:17.702370 8464107584 model_lib_v2.py:705] Step 6700 per-step time 0.422s
# INFO:tensorflow:{'Loss/classification_loss': 0.064467065,
#  'Loss/localization_loss': 0.034123663,
#  'Loss/regularization_loss': 0.12161735,
#  'Loss/total_loss': 0.22020808,
#  'learning_rate': 0.077358514}
# I0206 03:05:17.702591 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.064467065,
#  'Loss/localization_loss': 0.034123663,
#  'Loss/regularization_loss': 0.12161735,
#  'Loss/total_loss': 0.22020808,
#  'learning_rate': 0.077358514}
# INFO:tensorflow:Step 6800 per-step time 0.423s
# I0206 03:06:00.048289 8464107584 model_lib_v2.py:705] Step 6800 per-step time 0.423s
# INFO:tensorflow:{'Loss/classification_loss': 0.06462554,
#  'Loss/localization_loss': 0.023022646,
#  'Loss/regularization_loss': 0.12103103,
#  'Loss/total_loss': 0.20867923,
#  'learning_rate': 0.0772661}
# I0206 03:06:00.048509 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06462554,
#  'Loss/localization_loss': 0.023022646,
#  'Loss/regularization_loss': 0.12103103,
#  'Loss/total_loss': 0.20867923,
#  'learning_rate': 0.0772661}
# INFO:tensorflow:Step 6900 per-step time 0.426s
# I0206 03:06:42.621509 8464107584 model_lib_v2.py:705] Step 6900 per-step time 0.426s
# INFO:tensorflow:{'Loss/classification_loss': 0.071604684,
#  'Loss/localization_loss': 0.06618847,
#  'Loss/regularization_loss': 0.12047479,
#  'Loss/total_loss': 0.25826794,
#  'learning_rate': 0.077172145}
# I0206 03:06:42.621734 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.071604684,
#  'Loss/localization_loss': 0.06618847,
#  'Loss/regularization_loss': 0.12047479,
#  'Loss/total_loss': 0.25826794,
#  'learning_rate': 0.077172145}
# ...
# INFO:tensorflow:Step 7300 per-step time 0.441s
# I0206 03:09:38.120511 8464107584 model_lib_v2.py:705] Step 7300 per-step time 0.441s
# INFO:tensorflow:{'Loss/classification_loss': 0.08220541,
#  'Loss/localization_loss': 0.03354622,
#  'Loss/regularization_loss': 0.121273115,
#  'Loss/total_loss': 0.23702474,
#  'learning_rate': 0.07678111}
# I0206 03:09:38.120754 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08220541,
#  'Loss/localization_loss': 0.03354622,
#  'Loss/regularization_loss': 0.121273115,
#  'Loss/total_loss': 0.23702474,
#  'learning_rate': 0.07678111}
# INFO:tensorflow:Step 7400 per-step time 0.442s
# I0206 03:10:22.320289 8464107584 model_lib_v2.py:705] Step 7400 per-step time 0.442s
# INFO:tensorflow:{'Loss/classification_loss': 0.1281327,
#  'Loss/localization_loss': 0.062852666,
#  'Loss/regularization_loss': 0.120738596,
#  'Loss/total_loss': 0.31172395,
#  'learning_rate': 0.076679565}
# I0206 03:10:22.320496 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1281327,
#  'Loss/localization_loss': 0.062852666,
#  'Loss/regularization_loss': 0.120738596,
#  'Loss/total_loss': 0.31172395,
#  'learning_rate': 0.076679565}
# INFO:tensorflow:Step 7500 per-step time 0.436s
# I0206 03:11:05.951467 8464107584 model_lib_v2.py:705] Step 7500 per-step time 0.436s
# INFO:tensorflow:{'Loss/classification_loss': 0.072081335,
#  'Loss/localization_loss': 0.05617878,
#  'Loss/regularization_loss': 0.12018038,
#  'Loss/total_loss': 0.24844049,
#  'learning_rate': 0.0765765}
# I0206 03:11:05.951881 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.072081335,
#  'Loss/localization_loss': 0.05617878,
#  'Loss/regularization_loss': 0.12018038,
#  'Loss/total_loss': 0.24844049,
#  'learning_rate': 0.0765765}
# INFO:tensorflow:Step 7600 per-step time 0.445s
# I0206 03:11:50.422416 8464107584 model_lib_v2.py:705] Step 7600 per-step time 0.445s
# INFO:tensorflow:{'Loss/classification_loss': 0.07957237,
#  'Loss/localization_loss': 0.049635638,
#  'Loss/regularization_loss': 0.119593546,
#  'Loss/total_loss': 0.24880156,
#  'learning_rate': 0.07647194}
# I0206 03:11:50.422715 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07957237,
#  'Loss/localization_loss': 0.049635638,
#  'Loss/regularization_loss': 0.119593546,
#  'Loss/total_loss': 0.24880156,
#  'learning_rate': 0.07647194}
# INFO:tensorflow:Step 7700 per-step time 0.440s
# I0206 03:12:34.461479 8464107584 model_lib_v2.py:705] Step 7700 per-step time 0.440s
# INFO:tensorflow:{'Loss/classification_loss': 0.07383382,
#  'Loss/localization_loss': 0.02330152,
#  'Loss/regularization_loss': 0.119072005,
#  'Loss/total_loss': 0.21620736,
#  'learning_rate': 0.07636588}
# I0206 03:12:34.461690 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07383382,
#  'Loss/localization_loss': 0.02330152,
#  'Loss/regularization_loss': 0.119072005,
#  'Loss/total_loss': 0.21620736,
#  'learning_rate': 0.07636588}
# INFO:tensorflow:Step 7800 per-step time 0.440s
# I0206 03:13:18.507445 8464107584 model_lib_v2.py:705] Step 7800 per-step time 0.440s
# INFO:tensorflow:{'Loss/classification_loss': 0.04874791,
#  'Loss/localization_loss': 0.018813996,
#  'Loss/regularization_loss': 0.118505575,
#  'Loss/total_loss': 0.18606748,
#  'learning_rate': 0.07625833}
# I0206 03:13:18.507846 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.04874791,
#  'Loss/localization_loss': 0.018813996,
#  'Loss/regularization_loss': 0.118505575,
#  'Loss/total_loss': 0.18606748,
#  'learning_rate': 0.07625833}
# INFO:tensorflow:Step 7900 per-step time 0.443s
# I0206 03:14:02.794847 8464107584 model_lib_v2.py:705] Step 7900 per-step time 0.443s
# INFO:tensorflow:{'Loss/classification_loss': 0.077314556,
#  'Loss/localization_loss': 0.027035417,
#  'Loss/regularization_loss': 0.11793083,
#  'Loss/total_loss': 0.2222808,
#  'learning_rate': 0.07614928}
# I0206 03:14:02.795063 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.077314556,
#  'Loss/localization_loss': 0.027035417,
#  'Loss/regularization_loss': 0.11793083,
#  'Loss/total_loss': 0.2222808,
#  'learning_rate': 0.07614928}
# INFO:tensorflow:Step 8000 per-step time 0.441s
# I0206 03:14:46.889117 8464107584 model_lib_v2.py:705] Step 8000 per-step time 0.441s
# INFO:tensorflow:{'Loss/classification_loss': 0.05078303,
#  'Loss/localization_loss': 0.031559214,
#  'Loss/regularization_loss': 0.11741311,
#  'Loss/total_loss': 0.19975537,
#  'learning_rate': 0.07603875}
# I0206 03:14:46.889347 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.05078303,
#  'Loss/localization_loss': 0.031559214,
#  'Loss/regularization_loss': 0.11741311,
#  'Loss/total_loss': 0.19975537,
#  'learning_rate': 0.07603875}
# INFO:tensorflow:Step 8100 per-step time 0.448s
# I0206 03:15:31.680939 8464107584 model_lib_v2.py:705] Step 8100 per-step time 0.448s
# INFO:tensorflow:{'Loss/classification_loss': 0.104370676,
#  'Loss/localization_loss': 0.053924672,
#  'Loss/regularization_loss': 0.11687894,
#  'Loss/total_loss': 0.2751743,
#  'learning_rate': 0.07592674}
# I0206 03:15:31.681216 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.104370676,
#  'Loss/localization_loss': 0.053924672,
#  'Loss/regularization_loss': 0.11687894,
#  'Loss/total_loss': 0.2751743,
#  'learning_rate': 0.07592674}
# INFO:tensorflow:Step 8200 per-step time 0.443s
# I0206 03:16:16.020249 8464107584 model_lib_v2.py:705] Step 8200 per-step time 0.443s
# INFO:tensorflow:{'Loss/classification_loss': 0.06854286,
#  'Loss/localization_loss': 0.05789692,
#  'Loss/regularization_loss': 0.11631119,
#  'Loss/total_loss': 0.24275097,
#  'learning_rate': 0.075813256}
# I0206 03:16:16.021242 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06854286,
#  'Loss/localization_loss': 0.05789692,
#  'Loss/regularization_loss': 0.11631119,
#  'Loss/total_loss': 0.24275097,
#  'learning_rate': 0.075813256}
# INFO:tensorflow:Step 8300 per-step time 0.446s
# I0206 03:17:00.614940 8464107584 model_lib_v2.py:705] Step 8300 per-step time 0.446s
# INFO:tensorflow:{'Loss/classification_loss': 0.11835783,
#  'Loss/localization_loss': 0.032734856,
#  'Loss/regularization_loss': 0.1158682,
#  'Loss/total_loss': 0.2669609,
#  'learning_rate': 0.07569829}
# I0206 03:17:00.615141 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11835783,
#  'Loss/localization_loss': 0.032734856,
#  'Loss/regularization_loss': 0.1158682,
#  'Loss/total_loss': 0.2669609,
#  'learning_rate': 0.07569829}
# INFO:tensorflow:Step 8400 per-step time 0.450s
# I0206 03:17:45.584929 8464107584 model_lib_v2.py:705] Step 8400 per-step time 0.450s
# INFO:tensorflow:{'Loss/classification_loss': 0.05479935,
#  'Loss/localization_loss': 0.0354952,
#  'Loss/regularization_loss': 0.11534861,
#  'Loss/total_loss': 0.20564315,
#  'learning_rate': 0.07558186}
# I0206 03:17:45.585188 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.05479935,
#  'Loss/localization_loss': 0.0354952,
#  'Loss/regularization_loss': 0.11534861,
#  'Loss/total_loss': 0.20564315,
#  'learning_rate': 0.07558186}
# INFO:tensorflow:Step 8500 per-step time 0.451s
# I0206 03:18:30.707343 8464107584 model_lib_v2.py:705] Step 8500 per-step time 0.451s
# INFO:tensorflow:{'Loss/classification_loss': 0.12018887,
#  'Loss/localization_loss': 0.058823407,
#  'Loss/regularization_loss': 0.11484416,
#  'Loss/total_loss': 0.29385644,
#  'learning_rate': 0.07546397}
# I0206 03:18:30.707575 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12018887,
#  'Loss/localization_loss': 0.058823407,
#  'Loss/regularization_loss': 0.11484416,
#  'Loss/total_loss': 0.29385644,
#  'learning_rate': 0.07546397}
# INFO:tensorflow:Step 8600 per-step time 0.447s
# I0206 03:19:15.412538 8464107584 model_lib_v2.py:705] Step 8600 per-step time 0.447s
# INFO:tensorflow:{'Loss/classification_loss': 0.070242174,
#  'Loss/localization_loss': 0.018313453,
#  'Loss/regularization_loss': 0.11433443,
#  'Loss/total_loss': 0.20289004,
#  'learning_rate': 0.075344615}
# I0206 03:19:15.413426 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.070242174,
#  'Loss/localization_loss': 0.018313453,
#  'Loss/regularization_loss': 0.11433443,
#  'Loss/total_loss': 0.20289004,
#  'learning_rate': 0.075344615}
# INFO:tensorflow:Step 8700 per-step time 0.449s
# I0206 03:20:00.281436 8464107584 model_lib_v2.py:705] Step 8700 per-step time 0.449s
# INFO:tensorflow:{'Loss/classification_loss': 0.0712622,
#  'Loss/localization_loss': 0.04220876,
#  'Loss/regularization_loss': 0.11379585,
#  'Loss/total_loss': 0.22726682,
#  'learning_rate': 0.07522382}
# I0206 03:20:00.281684 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0712622,
#  'Loss/localization_loss': 0.04220876,
#  'Loss/regularization_loss': 0.11379585,
#  'Loss/total_loss': 0.22726682,
#  'learning_rate': 0.07522382}
# INFO:tensorflow:Step 8800 per-step time 0.448s
# I0206 03:20:45.091016 8464107584 model_lib_v2.py:705] Step 8800 per-step time 0.448s
# INFO:tensorflow:{'Loss/classification_loss': 0.053302843,
#  'Loss/localization_loss': 0.016406886,
#  'Loss/regularization_loss': 0.11330925,
#  'Loss/total_loss': 0.18301897,
#  'learning_rate': 0.07510157}
# I0206 03:20:45.091248 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.053302843,
#  'Loss/localization_loss': 0.016406886,
#  'Loss/regularization_loss': 0.11330925,
#  'Loss/total_loss': 0.18301897,
#  'learning_rate': 0.07510157}
# INFO:tensorflow:Step 8900 per-step time 0.452s
# I0206 03:21:30.250236 8464107584 model_lib_v2.py:705] Step 8900 per-step time 0.452s
# INFO:tensorflow:{'Loss/classification_loss': 0.067698516,
#  'Loss/localization_loss': 0.02278637,
#  'Loss/regularization_loss': 0.11276425,
#  'Loss/total_loss': 0.20324913,
#  'learning_rate': 0.074977875}
# I0206 03:21:30.250485 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.067698516,
#  'Loss/localization_loss': 0.02278637,
#  'Loss/regularization_loss': 0.11276425,
#  'Loss/total_loss': 0.20324913,
#  'learning_rate': 0.074977875}
# INFO:tensorflow:Step 9000 per-step time 0.463s
# I0206 03:22:16.556441 8464107584 model_lib_v2.py:705] Step 9000 per-step time 0.463s
# INFO:tensorflow:{'Loss/classification_loss': 0.12921669,
#  'Loss/localization_loss': 0.035452712,
#  'Loss/regularization_loss': 0.112259775,
#  'Loss/total_loss': 0.27692917,
#  'learning_rate': 0.07485275}
# I0206 03:22:16.557482 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12921669,
#  'Loss/localization_loss': 0.035452712,
#  'Loss/regularization_loss': 0.112259775,
#  'Loss/total_loss': 0.27692917,
#  'learning_rate': 0.07485275}
# INFO:tensorflow:Step 9100 per-step time 0.459s
# I0206 03:23:02.487820 8464107584 model_lib_v2.py:705] Step 9100 per-step time 0.459s
# INFO:tensorflow:{'Loss/classification_loss': 0.08437545,
#  'Loss/localization_loss': 0.028026797,
#  'Loss/regularization_loss': 0.111764364,
#  'Loss/total_loss': 0.2241666,
#  'learning_rate': 0.07472619}
# I0206 03:23:02.488064 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08437545,
#  'Loss/localization_loss': 0.028026797,
#  'Loss/regularization_loss': 0.111764364,
#  'Loss/total_loss': 0.2241666,
#  'learning_rate': 0.07472619}
# INFO:tensorflow:Step 9200 per-step time 0.455s
# I0206 03:23:47.963031 8464107584 model_lib_v2.py:705] Step 9200 per-step time 0.455s
# INFO:tensorflow:{'Loss/classification_loss': 0.088620566,
#  'Loss/localization_loss': 0.028353745,
#  'Loss/regularization_loss': 0.11128798,
#  'Loss/total_loss': 0.22826229,
#  'learning_rate': 0.07459819}
# I0206 03:23:47.963279 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.088620566,
#  'Loss/localization_loss': 0.028353745,
#  'Loss/regularization_loss': 0.11128798,
#  'Loss/total_loss': 0.22826229,
#  'learning_rate': 0.07459819}
# INFO:tensorflow:Step 9300 per-step time 0.450s
# I0206 03:24:33.014305 8464107584 model_lib_v2.py:705] Step 9300 per-step time 0.450s
# INFO:tensorflow:{'Loss/classification_loss': 0.081343226,
#  'Loss/localization_loss': 0.039520193,
#  'Loss/regularization_loss': 0.11080264,
#  'Loss/total_loss': 0.23166606,
#  'learning_rate': 0.074468784}
# I0206 03:24:33.014544 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.081343226,
#  'Loss/localization_loss': 0.039520193,
#  'Loss/regularization_loss': 0.11080264,
#  'Loss/total_loss': 0.23166606,
#  'learning_rate': 0.074468784}
# INFO:tensorflow:Step 9400 per-step time 0.454s
# I0206 03:25:18.438647 8464107584 model_lib_v2.py:705] Step 9400 per-step time 0.454s
# INFO:tensorflow:{'Loss/classification_loss': 0.055091683,
#  'Loss/localization_loss': 0.009506257,
#  'Loss/regularization_loss': 0.11026864,
#  'Loss/total_loss': 0.17486659,
#  'learning_rate': 0.074337944}
# I0206 03:25:18.439723 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.055091683,
#  'Loss/localization_loss': 0.009506257,
#  'Loss/regularization_loss': 0.11026864,
#  'Loss/total_loss': 0.17486659,
#  'learning_rate': 0.074337944}
# INFO:tensorflow:Step 9500 per-step time 0.456s
# I0206 03:26:04.042540 8464107584 model_lib_v2.py:705] Step 9500 per-step time 0.456s
# INFO:tensorflow:{'Loss/classification_loss': 0.14114678,
#  'Loss/localization_loss': 0.05255919,
#  'Loss/regularization_loss': 0.10976686,
#  'Loss/total_loss': 0.30347285,
#  'learning_rate': 0.074205704}
# I0206 03:26:04.042786 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.14114678,
#  'Loss/localization_loss': 0.05255919,
#  'Loss/regularization_loss': 0.10976686,
#  'Loss/total_loss': 0.30347285,
#  'learning_rate': 0.074205704}
# INFO:tensorflow:Step 9600 per-step time 0.458s
# I0206 03:26:49.814565 8464107584 model_lib_v2.py:705] Step 9600 per-step time 0.458s
# INFO:tensorflow:{'Loss/classification_loss': 0.079433,
#  'Loss/localization_loss': 0.034000844,
#  'Loss/regularization_loss': 0.10926838,
#  'Loss/total_loss': 0.22270223,
#  'learning_rate': 0.07407206}
# I0206 03:26:49.814794 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.079433,
#  'Loss/localization_loss': 0.034000844,
#  'Loss/regularization_loss': 0.10926838,
#  'Loss/total_loss': 0.22270223,
#  'learning_rate': 0.07407206}
# INFO:tensorflow:Step 9700 per-step time 0.460s
# I0206 03:27:35.785047 8464107584 model_lib_v2.py:705] Step 9700 per-step time 0.460s
# INFO:tensorflow:{'Loss/classification_loss': 0.07269873,
#  'Loss/localization_loss': 0.022478348,
#  'Loss/regularization_loss': 0.10879422,
#  'Loss/total_loss': 0.2039713,
#  'learning_rate': 0.073937014}
# I0206 03:27:35.785289 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07269873,
#  'Loss/localization_loss': 0.022478348,
#  'Loss/regularization_loss': 0.10879422,
#  'Loss/total_loss': 0.2039713,
#  'learning_rate': 0.073937014}
# INFO:tensorflow:Step 9800 per-step time 0.470s
# I0206 03:28:22.787966 8464107584 model_lib_v2.py:705] Step 9800 per-step time 0.470s
# INFO:tensorflow:{'Loss/classification_loss': 0.0900716,
#  'Loss/localization_loss': 0.03178411,
#  'Loss/regularization_loss': 0.10827465,
#  'Loss/total_loss': 0.23013037,
#  'learning_rate': 0.07380057}
# I0206 03:28:22.789115 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0900716,
#  'Loss/localization_loss': 0.03178411,
#  'Loss/regularization_loss': 0.10827465,
#  'Loss/total_loss': 0.23013037,
#  'learning_rate': 0.07380057}
# INFO:tensorflow:Step 9900 per-step time 0.473s
# I0206 03:29:10.096376 8464107584 model_lib_v2.py:705] Step 9900 per-step time 0.473s
# INFO:tensorflow:{'Loss/classification_loss': 0.07614438,
#  'Loss/localization_loss': 0.034331165,
#  'Loss/regularization_loss': 0.107779756,
#  'Loss/total_loss': 0.21825531,
#  'learning_rate': 0.073662736}
# I0206 03:29:10.096676 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07614438,
#  'Loss/localization_loss': 0.034331165,
#  'Loss/regularization_loss': 0.107779756,
#  'Loss/total_loss': 0.21825531,
#  'learning_rate': 0.073662736}
# INFO:tensorflow:Step 10000 per-step time 0.455s
# I0206 03:29:55.584862 8464107584 model_lib_v2.py:705] Step 10000 per-step time 0.455s
# INFO:tensorflow:{'Loss/classification_loss': 0.060443845,
#  'Loss/localization_loss': 0.0125248525,
#  'Loss/regularization_loss': 0.10733553,
#  'Loss/total_loss': 0.18030423,
#  'learning_rate': 0.07352352}
# I0206 03:29:55.585272 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.060443845,
#  'Loss/localization_loss': 0.0125248525,
#  'Loss/regularization_loss': 0.10733553,
#  'Loss/total_loss': 0.18030423,
#  'learning_rate': 0.07352352}

# %% [markdown]
# # 7. LOAD trained model from checkpoint

# %%
import os
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder

# %% [markdown]
# **- UPDATE .ckpt to latest on in my_ssd_mobnet -**

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
# UPDATE ckpt-XX to latest checkpoint
ckpt.restore(os.path.join(CHECKPOINT_PATH, 'ckpt-11')).expect_partial() 

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 8 - RTOD pretrained sign language gloss detection

# %%
import cv2
import numpy as np
# added to ensure stream closes properly
import tensorflow as tf
from object_detection.utils import visualization_utils as viz_utils

# %%
category_index = label_map_util.create_category_index_from_labelmap(ANNOTATION_PATH+'/label_map.pbtxt')

# %%
# Setup capture
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
# start webcam and log detected objects with confidence score

import cv2
import numpy as np
import tensorflow as tf
from object_detection.utils import visualization_utils as viz_utils
import time

# Define a function to log detected objects
def log_detected_objects(detections, category_index):
    log = []
    for i in range(detections['num_detections']):
        # define confidence with which glosses need to be detected
        if detections['detection_scores'][i] >= 0.65:
            class_id = detections['detection_classes'][i]
            if class_id in category_index:
                class_name = category_index[class_id]['name']
                score = detections['detection_scores'][i]
                log.append((class_name, score))
    return log

# Initialize logging list
detected_objects_log = []
last_log_time = time.time()

# Initialize the camera
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video source.")
else:
    try:
        while True: 
            ret, frame = cap.read()
            if not ret:
                print("Error: Failed to capture frame.")
                break

            image_np = np.array(frame)
            
            input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
            detections = detect_fn(input_tensor)
            
            num_detections = int(detections.pop('num_detections'))
            detections = {key: value[0, :num_detections].numpy()
                          for key, value in detections.items()}
            detections['num_detections'] = num_detections

            # detection_classes should be ints.
            detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

            label_id_offset = 1
            image_np_with_detections = image_np.copy()

            viz_utils.visualize_boxes_and_labels_on_image_array(
                        image_np_with_detections,
                        detections['detection_boxes'],
                        detections['detection_classes'] + label_id_offset,
                        detections['detection_scores'],
                        category_index,
                        use_normalized_coordinates=True,
                        max_boxes_to_draw=5,
                        min_score_thresh=.5,
                        agnostic_mode=False)

            cv2.imshow('object detection', cv2.resize(image_np_with_detections, (800, 600)))

            # Log detected objects with a score of over 80%, but only once every second
            current_time = time.time()
            if current_time - last_log_time >= 1:
                logged_objects = log_detected_objects(detections, category_index)
                detected_objects_log.extend(logged_objects)
                print(f"Logged objects: {logged_objects}")  # Print the logged objects with confidence scores
                last_log_time = current_time
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    finally:
        cap.release()
        cv2.destroyAllWindows()
        # Print the log of detected objects in list format
        detected_objects = [(entry[0], entry[1]) for entry in detected_objects_log]
        print(f"\ndetected_objects_log = {detected_objects}")
# Out:
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: [('montag', 0.9165066)]
# Logged objects: [('auch', 0.9710749)]
# Logged objects: []
# Logged objects: [('mehr', 0.8855656)]
# Logged objects: [('wolke', 0.9841085)]
# Logged objects: [('wolke', 0.97923976)]
# Logged objects: [('wolke', 0.9834555)]
# Logged objects: [('als', 0.9036937)]
# Logged objects: []
# Logged objects: [('sonne', 0.80104715)]
# Logged objects: [('sonne', 0.9842377)]
# Logged objects: [('ueberwiegend', 0.886569)]
# Logged objects: []
# Logged objects: [('regen', 0.83940244)]
# Logged objects: [('regen', 0.8750665)]
# Logged objects: [('als', 0.72949636)]
#
# detected_objects_log = [('montag', 0.9165066), ('auch', 0.9710749), ('mehr', 0.8855656), ('wolke', 0.9841085), ('wolke', 0.97923976), ('wolke', 0.9834555), ('als', 0.9036937), ('sonne', 0.80104715), ('sonne', 0.9842377), ('ueberwiegend', 0.886569), ('regen', 0.83940244), ('regen', 0.8750665), ('als', 0.72949636)]

# %%
# Remove duplicates/objects appearing multiple times after each other
def remove_consecutive_duplicates(detected_objects):
    return [detected_objects[i] for i in range(len(detected_objects)) if i == 0 or detected_objects[i][0] != detected_objects[i-1][0]]

# Create cleaned_detected_objects_log
cleaned_detected_objects_log = remove_consecutive_duplicates(detected_objects_log)

# Print the cleaned objects with confidence values
print("\ncleaned_detected_objects_log:")
for obj in cleaned_detected_objects_log:
    print(f"{obj[0]}: {obj[1]}")  # Assuming obj[1] is the confidence value
# Out:
# cleaned_detected_objects_log:
# montag: 0.9165065884590149
# auch: 0.9710748791694641
# mehr: 0.8855655789375305
# wolke: 0.9841085076332092
# als: 0.903693675994873
# sonne: 0.801047146320343
# ueberwiegend: 0.8865690231323242
# regen: 0.839402437210083
# als: 0.7294963598251343
